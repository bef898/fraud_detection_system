# %% [markdown]
# Data Anaysis and Preprocessing

# %% [markdown]
# importing liberaries

# %%
import os
import sys
import pandas as pd
import numpy as np

sys.path.append(os.path.abspath('../scripts'))
sys.path.append(os.path.abspath('..src'))

# %% [markdown]
# load data for all data types

# %%
fraud_data = pd.read_csv(r'C:\Users\befekadum\Documents\10x acadamy\week8and9\fraud_detection_system\data\Fraud_Data.csv')
credit_card_data = pd.read_csv(r'C:\Users\befekadum\Documents\10x acadamy\week8and9\fraud_detection_system\data\creditcard.csv')
ip_data = pd.read_csv(r'C:\Users\befekadum\Documents\10x acadamy\week8and9\fraud_detection_system\data\IpAddress_to_Country.csv')

# %%
fraud_data.head()
# Out:
#    user_id          signup_time        purchase_time  purchase_value  \
# 0    22058  2015-02-24 22:55:49  2015-04-18 02:47:11              34
# 1   333320  2015-06-07 20:39:50  2015-06-08 01:38:54              16
# 2     1359  2015-01-01 18:52:44  2015-01-01 18:52:45              15
# 3   150084  2015-04-28 21:13:25  2015-05-04 13:54:50              44
# 4   221365  2015-07-21 07:09:52  2015-09-09 18:40:53              39
#
#        device_id source browser sex  age    ip_address  class
# 0  QVPSPJUOCKZAR    SEO  Chrome   M   39  7.327584e+08      0
# 1  EOGFQPIZPYXFZ    Ads  Chrome   F   53  3.503114e+08      0
# 2  YSSKYOSJHPPLJ    SEO   Opera   M   53  2.621474e+09      1
# 3  ATGTXKYKUDUQN    SEO  Safari   M   41  3.840542e+09      0
# 4  NAUITBZFJKHWW    Ads  Safari   M   45  4.155831e+08      0

# %%
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
ip_data.head()
# Out:
#    lower_bound_ip_address  upper_bound_ip_address    country
# 0              16777216.0                16777471  Australia
# 1              16777472.0                16777727      China
# 2              16777728.0                16778239      China
# 3              16778240.0                16779263  Australia
# 4              16779264.0                16781311      China

# %% [markdown]
# Handle Missing values

# %%
from data_pro_function import data_pro

# %%
data_pro_new = data_pro

# %%
missing_frud_data = data_pro_new.percent_missing(fraud_data,fraud_data)
missing_frud_data
# Out:
# np.float64(0.0)

# %% [markdown]
# which shows there is no missing values in the data fraud.csv

# %%
missing_credit_card_data = data_pro_new.percent_missing(credit_card_data,credit_card_data)
missing_credit_card_data
# Out:
# np.float64(0.0)

# %% [markdown]
# which shows there is no missing values in credit_card_data csv

# %%
missing_ip_data = data_pro_new.percent_missing(ip_data,ip_data)
missing_ip_data
# Out:
# np.float64(0.0)

# %% [markdown]
# which shows there is no missing values in ip data csv

# %% [markdown]
# Data celaning remove duplicates and correct data types

# %%
fraud_data
# Out:
#         user_id          signup_time        purchase_time  purchase_value  \
# 0         22058  2015-02-24 22:55:49  2015-04-18 02:47:11              34
# 1        333320  2015-06-07 20:39:50  2015-06-08 01:38:54              16
# 2          1359  2015-01-01 18:52:44  2015-01-01 18:52:45              15
# 3        150084  2015-04-28 21:13:25  2015-05-04 13:54:50              44
# 4        221365  2015-07-21 07:09:52  2015-09-09 18:40:53              39
# ...         ...                  ...                  ...             ...
# 151107   345170  2015-01-27 03:03:34  2015-03-29 00:30:47              43
# 151108   274471  2015-05-15 17:43:29  2015-05-26 12:24:39              35
# 151109   368416  2015-03-03 23:07:31  2015-05-20 07:07:47              40
# 151110   207709  2015-07-09 20:06:07  2015-09-07 09:34:46              46
# 151111   138208  2015-06-10 07:02:20  2015-07-21 02:03:53              20
#
#             device_id  source browser sex  age    ip_address  class
# ...

# %%
duplicates_frud_data = data_pro_new.drop_duplicate(fraud_data,fraud_data)

duplicates_frud_data
# Out:
#         user_id          signup_time        purchase_time  purchase_value  \
# 0         22058  2015-02-24 22:55:49  2015-04-18 02:47:11              34
# 1        333320  2015-06-07 20:39:50  2015-06-08 01:38:54              16
# 2          1359  2015-01-01 18:52:44  2015-01-01 18:52:45              15
# 3        150084  2015-04-28 21:13:25  2015-05-04 13:54:50              44
# 4        221365  2015-07-21 07:09:52  2015-09-09 18:40:53              39
# ...         ...                  ...                  ...             ...
# 151107   345170  2015-01-27 03:03:34  2015-03-29 00:30:47              43
# 151108   274471  2015-05-15 17:43:29  2015-05-26 12:24:39              35
# 151109   368416  2015-03-03 23:07:31  2015-05-20 07:07:47              40
# 151110   207709  2015-07-09 20:06:07  2015-09-07 09:34:46              46
# 151111   138208  2015-06-10 07:02:20  2015-07-21 02:03:53              20
#
#             device_id  source browser sex  age    ip_address  class
# ...

# %% [markdown]
# this shows there is no duplicate values on the data set

# %%
credit_card_data
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
duplicates_credit_card = data_pro_new.drop_duplicate(credit_card_data,credit_card_data)

duplicates_credit_card
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %% [markdown]
# agin there is no dupicates

# %%
ip_data
# Out:
#         lower_bound_ip_address  upper_bound_ip_address    country
# 0                 1.677722e+07                16777471  Australia
# 1                 1.677747e+07                16777727      China
# 2                 1.677773e+07                16778239      China
# 3                 1.677824e+07                16779263  Australia
# 4                 1.677926e+07                16781311      China
# ...                        ...                     ...        ...
# 138841            3.758092e+09              3758093311  Hong Kong
# 138842            3.758093e+09              3758094335      India
# 138843            3.758095e+09              3758095871      China
# 138844            3.758096e+09              3758096127  Singapore
# 138845            3.758096e+09              3758096383  Australia
#
# [138846 rows x 3 columns]

# %%
duplicates_ip_data = data_pro_new.drop_duplicate(ip_data,ip_data)

duplicates_ip_data
# Out:
#         lower_bound_ip_address  upper_bound_ip_address    country
# 0                 1.677722e+07                16777471  Australia
# 1                 1.677747e+07                16777727      China
# 2                 1.677773e+07                16778239      China
# 3                 1.677824e+07                16779263  Australia
# 4                 1.677926e+07                16781311      China
# ...                        ...                     ...        ...
# 138841            3.758092e+09              3758093311  Hong Kong
# 138842            3.758093e+09              3758094335      India
# 138843            3.758095e+09              3758095871      China
# 138844            3.758096e+09              3758096127  Singapore
# 138845            3.758096e+09              3758096383  Australia
#
# [138846 rows x 3 columns]

# %% [markdown]
# no duplicate data found
